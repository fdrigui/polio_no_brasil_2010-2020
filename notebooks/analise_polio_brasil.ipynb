# %% [markdown]
# <a id='intro'></a>
# # Projeto: Retrato da cobertura vacinal contra **Póliomielite** no Brasil na ultima decada (2010 - 2020)
# A **Póliomielite**, também conhecida como **Pólio** ou então **Paralisia Infantil** é uma doença viral, sem cura, que em casos graves, degenera a função motora dos membros inferiores, podendo inclusive levar ao obito.<br>
# Segundo o portal Veja-Saúde, em sua matéria entitulada [Estamos mesmo livres da Poliomelite?](https://saude.abril.com.br/blog/com-a-palavra/estamos-mesmo-livres-da-poliomielite/) consta que a **OMS** (Organização Mundial da Saúde), estipulou uma **meta de 95%** para a cobertura vacinal contra a **Pólio** no o plano de erradicação da doença no mundo.<br>
# Qual é o Histórico da cobertura vacinal contra a **Pólio** no Brasil? O Brasil cumpre a meta estipulada pela OMS de 95% de cobertura vacinal contra **Pólio**? Essas e outras questões vão ser respondidas nessa pesquisa.

# %% [markdown]
# <a id='objetivo'></a>
# ## Objetivo
# Esse projeto tem como objetivo mostrar a situação da vacina contra a **Pólio** no Brasil, mobilizando assim o setor público e privado para o tema de alta relevância para a saúde pública.<br>
# A pesquisa sobre a cobertura vacinal no Brasil contra a **Pólio** na ultima decada majoritariamente utilizará a base de dados do SUS, também conhecido como [DATASUS](http://www2.datasus.gov.br/).<br> No decorrer do projeto, será dada maiores informações relacionadas a exportação dos dados, na medida em que se fizer necessário para a análise.<br>

# %% [markdown]
# <a id='Escopo'></a>
# ## Escopo
# ### Faz parte
# - O projeto tem como principal característica a análise em carater **Nacional**, fazendo o uso das informações Estaduais ou até municipais para melhor entender o todo.
# - O projeto se baseia principalmente nas informações contidas no *DATASUS*
# - O projeto vai focar nos dados relacionados a **Poliomielite 1° dose** (Causa) e **Paralisia Flácida Aguda** (Efeito), podendo utilizar outras coberturas vacinais como base de comparação, e não como proósito principal de análise.
# - O projeto vai focar no período entre os anos de 2010 e 2020, que é suficiênte para se ter uma noção da evolução e de tendências.
# - O peojeto visa fazer uso dos dados d por estado ou município se for importante para a análise
#
# ### Não faz parte
# - Não faz parte do escopo as 2 vacinas de reforço contra a **Polio**, uma vez que os registros da dose de reforço começaram a ser armazenados a partir de 2013 e da dose de reforço aso 4 anos a partir de 2017.
# - Não faz parte do escopo a consideração do ano de 2021, uma vez que o mesmo se encontra incompleto.
# - Não faz parte do escopo uma análise estadual ou municipal minunciosa. Caso seja necessára, se fará para melhor compreensão dos dados de carater nacional.
#
#
# ### Observações importantes
# - O ano de **2020** foi incluído na análise, mais precisa ser considerado com cautela, uma vez que por causa da **pandemia de COVID-19** os hábitos mudaram e as restrições e confinamentos nesse período podem ter alterado o padrão de vacinação.

# %% [markdown]
# <a id='dados'></a>
# ## Dados
# <a id='cobertura_brasil'></a>
# ### 1. Cobertura vacinal no Brasil por imuno
# Os dados podem ser encontrados no seguinte caminho:<br>
# Portal da Saúde (SUS) >> Assistência à saúde >> Imunizações >> Cobertura<br>
# ou direto pelo [link](http://tabnet.datasus.gov.br/cgi/dhdat.exe?bd_pni/cpnibr.def)<br>
# **IMUNIZAÇÕES - COBERTURA - BRASIL**<br>
# **Linha:** Imuno<br>
# **Coluna:** Ano<br>
# **Medida:** Coberturas Vacinais<br>
# **Período Disponível:** 1994 - 2021<br>
# **Data da exportação:** 09/06/2021 00:29<br>
# **Caminho para o arquivo:** `../data/raw/cobertura_vacinal_brasil/cobertura_por_imuno_por_ano_1994-2021.csv`<br>
# *Maiores informações podem ser encontradas [aqui](http://tabnet.datasus.gov.br/cgi/pni/Imun_cobertura_desde_1994.pdf)*
#
# <a id='cobertura_estados'></a>
# ### 2. Cobertura vacinal no Brasil por estado e por imuno
# Os dados podem ser encontrados no seguinte caminho:<br>
# Portal da Saúde (SUS) >> Assistência à saúde >> Imunizações >> Cobertura<br>
# ou direto pelo [link](http://tabnet.datasus.gov.br/cgi/dhdat.exe?bd_pni/cpnibr.def)<br>
# **IMUNIZAÇÕES - COBERTURA - BRASIL**<br>
# **Linha:** UF<br>
# **Coluna:** Imuno<br>
# **Medida:** Coberturas Vacinais<br>
# **Período Disponível:** 1994 - 2021 (um arquivo por ano)<br>
# **Data da exportação:** 07/06/2021 19:05<br>
# **Caminho para o arquivo:** `../data/raw/cobertura_vacinal_uf/cobertura_por_imuno_por_uf_[1994...2020].csv`<br>
# *Maiores informações podem ser encontradas [aqui](http://tabnet.datasus.gov.br/cgi/pni/Imun_cobertura_desde_1994.pdf)*
#
# <a id='cobertura_municipio'></a>
# ### 3. Cobertura vacinal no Brasil por municipio e por imuno em 2019
# Os dados podem ser encontrados no seguinte caminho:<br>
# Portal da Saúde (SUS) >> Assistência à saúde >> Imunizações >> Cobertura<br>
# ou direto pelo [link](http://tabnet.datasus.gov.br/cgi/dhdat.exe?bd_pni/cpnibr.def)<br>
# **IMUNIZAÇÕES - COBERTURA - BRASIL**<br>
# **Linha:** Municipio<br>
# **Coluna:** Imuno<br>
# **Medida:** Coberturas Vacinais<br>
# **Período Disponível:** 2019<br>
# **Data da exportação:** 09/06/2021 01:01<br>
# **Caminho para o arquivo:** `../data/raw/cobertura_vacinal_municipio/cobertura_vacinal_por_municipio_2019.csv`<br>
# *Maiores informações podem ser encontradas [aqui](http://tabnet.datasus.gov.br/cgi/pni/Imun_cobertura_desde_1994.pdf)*
#
# <a id='morbidade_paf'></a>
# ### 4. Notificações por Paralisia Flacida Aguda no Brasil por Ano
# Os dados podem ser encontrados no seguinte caminho:<br>
# Portal da Saúde (SUS) >> Epidemiológicas e Morbidade >> Doenças e Agravos de Notificação - 2007 em diante (SINAN) >> Paralisia Flácida Aguda >> Brasil por região, UF e Município<br>
# ou direto pelo [link](http://tabnet.datasus.gov.br/cgi/deftohtm.exe?sinannet/cnv/pfabr.def)<br>
# **PARALISIA FLÁCIDA AGUDA - Notificações registradas no Sistema de Informação de Agravos de Notificação - Brasil**<br>
# **Linha:** UF de residência<br>
# **Coluna:** Ano 1° Sintomas<br>
# **Medida:** Notificações<br>
# **Período Disponível:** 2007-2019<br>
# **Data da exportação:** 09/06/2021 01:01<br>
# **Caminho para o arquivo:** `../data/raw/cobertura_vacinal_municipio/cobertura_vacinal_por_municipio_2019.csv`<br>
# *Maiores informações podem ser encontradas [aqui](http://tabnet.datasus.gov.br/cgi/pni/Imun_cobertura_desde_1994.pdf)*
#
# <a id='tab_uf'></a>
# ### 5. Tabela de referência de Unidade Federativa
# Tabela com a referência entre:<br>
# 1. Código do UF (ex: 11 ; 12 ; 13 )<br>
# 2. Nome do UF (ex: Rondônia; Acre; Amazonas)<br>
# 3. UF (ex: RO; AC; AM)<br>
# Link: https://www.oobj.com.br/bc/article/quais-os-c%C3%B3digos-de-cada-uf-no-brasil-465.html<br>
# O Objetivo dessa consulta é relacionar o **Nome do Município** e o **UF**.
#
# <a id='ibge_municipios'></a>
# ### 6. Tabela de referência de Municípios
# Tabelas aninhadas por estado, com a referência entre:<br>
# 1. Estado (Nome do UF)<br>
# 2. Nome do Município<br>
# 3. Código do Município<br>
# Link: https://www.ibge.gov.br/explica/codigos-dos-municipios.php<br>
# O Objetivo dessa consulta é relacionar o **Nome do Município** e o **UF**.

# %% [markdown]
# ## *Import* das bibliotecas

# %%
# Import das bibliotecas
import pandas as pd # Biblioteca de manipulação e análise de dados
import glob # Biblioteca para trabalhar com caminhos (Paths) e arquivos
from matplotlib import pyplot as plt # Biblioteca para criação de gráficos e visualização
import seaborn as sns # Biblioteca de visualização de dados baseado no Matplotlib
from scipy.stats import linregress # Biblioteca para análise de regressão linear

# Configuração
# Definição do estilo gráfico a ser renderizado pelo seaborn e matplotlib
plt.style.use('ggplot')
# Evita imagens borradas
# %config InlineBackend.figure_format = 'retina'
sns.set_context('talk')
# Exibe menos casas decimais
pd.options.display.float_format = "{:,.3f}".format

# %% [markdown]
# ## Definição das funções

# %%
def le_cobertura_vacinal_por_imuno_no_brasil(path: str, imuno: str, rolling: int = 3, ignora_inicio: int = 0) -> pd.DataFrame:
    '''
    Function description
    
    Parameters
    ----------
    path :
    
    imuno :
    
    rolling :
    
    Returns
    -------
    DataFrame or TextParser
        A comma-separated values (csv) file is returned as two-dimensional
        data structure with labeled axes.

    Examples
    --------
    >>> le_cobertura_vacinal_por_imuno_no_brasil(path=r'data.csv', imuno='Poliomielite', rolling = 3)  # doctest: +SKIP
    '''
    
    # Cobertura da vacinação contra Poliomelite no Brasil
    cobertura_brasil = pd.read_csv(path, sep=';', decimal=',', encoding='ISO-8859-1',
                                   skipfooter=2, na_values = 0.000, engine='python')
    
    # Transpõe Linhas e Colunas
    cobertura_brasil = cobertura_brasil.set_index('Imuno').T
    
    # Remove a linha de totais do DataFrame
    cobertura_brasil = cobertura_brasil.drop(' Total')
    
    # Extrai somente a coluna do imuno desejado do Dataframe de imunos/ano
    cobertura_brasil = cobertura_brasil[[imuno]]
    
    cobertura_brasil = cobertura_brasil.dropna()
    
    cobertura_brasil = cobertura_brasil[ignora_inicio:]
    
    # Renomeia a coluna Index de 'Imuno' para 'ano'
    cobertura_brasil.columns.name = 'ano'
    
    # Alterando o tipo do index de 'Object' para 'Int'
    cobertura_brasil.index = cobertura_brasil.index.astype(int)
    
    # Feature1: Média móvel de tamanho 3 na 'cobertura_polio_no_brasil'
    cobertura_brasil[f'rolling_{rolling}'] = cobertura_brasil[imuno].rolling(rolling).mean()
    
    # Feature2: Faz a diferenciação da média mível para ter uma 'velocidade' de alteração na média móvel da cobertura
    cobertura_brasil['rolling_vel'] = cobertura_brasil[f'rolling_{rolling}'].diff()
    
    # Feature3: Faz a diferenciação da velocidade para ter uma 'aceleração' de alteração na média móvel da cobertura
    cobertura_brasil['rolling_acel'] = cobertura_brasil['rolling_vel'].diff()
    
    # Seleciona valores referentes a ultima decada (2010 até 2020) da cobertura de vacinação no Brasil
    cobertura_brasil = cobertura_brasil.loc[2010:2020]
    
    return cobertura_brasil

def le_cobertura_vacinal_por_imuno_no_brasil_por_estado(path: str, imuno: str, rolling: int = 3) -> pd.DataFrame:
    '''
    Function description
    
    Parameters
    ----------
    path :
    
    imuno :
    
    rolling :
    
    Returns
    -------
    DataFrame or TextParser
        A comma-separated values (csv) file is returned as two-dimensional
        data structure with labeled axes.

    Examples
    --------
    >>> le_cobertura_vacinal_por_imuno_no_brasil(path=r'data.csv', imuno='Poliomielite', rolling = 3)  # doctest: +SKIP
    '''
    # encontra todos os arquivos csv dentro da pasta 'Path'
    lista_de_arquivos = glob.glob(path + "/*.csv")

    # Cria um array vazio de dataframes
    lista_de_dataframe = []

    # Para cada arquivo encontrado na pasta, roda a abertura e tratamento inicial
    for arquivo in lista_de_arquivos:

        # Abre o arquivo csv e extrai a informação relacionada com a Poliomielite
        df = pd.read_csv(arquivo, sep=';', decimal=',', encoding='ISO-8859-1',usecols=['Unidade da Federação',imuno],
                         skipfooter=1, engine='python')
        # Renomeia nome das colunas
        df = df.rename(columns={'Unidade da Federação':'uf'})
        # Remove do UF o código do estado, EX: '11 Rondônia' -> 'Rondônia' | '52 Goiás' -> 'Goiás'
        df['uf'] = df['uf'].str[3:]
        # Extrai do nome do arquivo o ano relacionado com a informação
        df['ano'] = int(arquivo[-8:-4])
                
        # Adiciona o DataFrame lido na lista de DataFrames criados
        lista_de_dataframe.append(df)

    # Transforma uma lista de DataFrames em um único DataFrame    
    cobertura_uf = pd.concat(lista_de_dataframe, ignore_index=True)
    
    cobertura_uf = pd.pivot_table(data=cobertura_uf, values='Poliomielite', columns='uf', index='ano')

    # Para cada estado, calcula uma média móvel de periodo = 'rolling'
    for uf in cobertura_uf.columns:
        cobertura_uf[f'{uf}_rol_{rolling}'] = cobertura_uf[uf].rolling(rolling).mean()
        
    cobertura_uf = cobertura_uf.query('ano <= 2020 and ano >= 2010')
        
    # Faz o melt e concatena a cobertura vacinal raw com a média móvel
    uf_len = int(len(cobertura_uf.columns)/2)
    polio = cobertura_uf.iloc[:,:uf_len].reset_index().melt(id_vars='ano', var_name='uf', value_name='Poliomielite')
    polio_rol = cobertura_uf.iloc[:,uf_len:].reset_index().melt(id_vars='ano', var_name='uf_', value_name=f'Polio_rol{rolling}').drop(['ano', 'uf_'], axis=1)

    return pd.concat([polio, polio_rol], axis=1)

# %% [markdown]
# ## Avaliação da cobertura vacinal no Brasil contra a **Pólio** na ultima decada

# %%
# Abre arquivo de cobertura vacinal no Brasil
path = r'../data/raw/cobertura_vacinal_brasil/cobertura_por_imuno_por_ano_1994-2021.csv'
polio_no_brasil = le_cobertura_vacinal_por_imuno_no_brasil(path, 'Poliomielite')
polio_no_brasil.head()
# Out:
# ano   Poliomielite  rolling_3  rolling_vel  rolling_acel
# 2010        99.350    101.063       -2.027        -1.497
# 2011       101.330    101.447        0.383         2.410
# 2012        96.550     99.077       -2.370        -2.753
# 2013       100.710     99.530        0.453         2.823
# 2014        96.760     98.007       -1.523        -1.977

# %%
# Imprime a cobertura vacinal contra Polio da ultima década e a velocidade (diff)

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(16, 13), sharex='all', gridspec_kw={'height_ratios': [2.5, 1]})
fig.tight_layout(pad=3.5)
sns.lineplot(ax=axs[0], data=polio_no_brasil, x=polio_no_brasil.index, y='Poliomielite', color='#94AFC5')
sns.lineplot(ax=axs[0], data=polio_no_brasil, x=polio_no_brasil.index, y='rolling_3', marker='o', color='#174A7E')
axs[0].set_title('Cobertura vacinal contra Pólio na ultima decada', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[0].axhline(95,linestyle='--',linewidth=1, alpha=0.8, color='#C3514E', label='OMS Target')
axs[0].set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].set_ylabel('Cobertura Vacinal contra Pólio [%]', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].spines['bottom'].set_visible(True)
axs[0].spines['bottom'].set_color('#555655')
axs[0].spines['bottom'].set_linewidth(1)
axs[0].spines['left'].set_visible(True)
axs[0].spines['left'].set_color('#555655')
axs[0].spines['left'].set_linewidth(1)
axs[0].set_facecolor('xkcd:white')
axs[0].set_ylim(ymin=75, ymax=103)
axs[0].grid(False)
plt.yticks(fontname = "Arial", fontsize=12)
plt.xticks(fontname = "Arial", fontsize=12)
axs[0].annotate(text='Cobertura Vacinal \ncontra Pólio (RAW)',
            xy=(2020, 75.86),
            xycoords='data',
            xytext=(10, -6),  # New param
            textcoords='offset points',
           color='#94AFC5',
           fontname = "Arial")  # New param
axs[0].annotate(text='Média Móvel (3)\nCobertura Vacinal contra Pólio',
            xy=(2020, 83.19),
            xycoords='data',
            xytext=(10, -15),  # New param
            textcoords='offset points',
           color='#174A7E',
           fontname = "Arial")  # New param

axs[0].annotate(text='Meta cobertura \n vacinal da OMS',
            xy=(2020, 95),
            xycoords='data',
            xytext=(55, -15),  # New param
            textcoords='offset points',
           color='#C3514E',
           fontname = "Arial")

axs[0].annotate(text='Em 2016 a cobertura\nvacinal cai abaixo de 95%',
            xy=(2015.65, 95),
            xycoords='data',
            xytext=(25, 50),
            textcoords='offset points',
            color='#C3514E',
           fontname = "Arial",
            fontsize=14,
            horizontalalignment='left',
            arrowprops={'color':'#C3514E', 'arrowstyle':'->'})

sns.lineplot(ax=axs[1], data=polio_no_brasil, x=polio_no_brasil.index, y='rolling_vel', color='#8F84D3', marker='o')
axs[1].axhline(0.0,linestyle='--',linewidth=1, alpha=0.8, color='#C3514E', label='OMS Target')
axs[1].set_title('Taxa de variação da Cobertura vacinal contra Pólio na ultima decada', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[1].set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].set_ylabel('Cobertura Vacinal contra Pólio [%  / ano]', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].spines['bottom'].set_visible(True)
axs[1].spines['bottom'].set_color('#555655')
axs[1].spines['bottom'].set_linewidth(1)
axs[1].spines['left'].set_visible(True)
axs[1].spines['left'].set_color('#555655')
axs[1].spines['left'].set_linewidth(1)
axs[1].set_facecolor('xkcd:white')
axs[1].grid(False)
plt.yticks(fontname = "Arial", fontsize=12)
plt.xticks(fontname = "Arial", fontsize=12)
axs[1].annotate(text='Taxa de variação da \ncobertura vacinal por ano',
            xy=(2020, -2.96),
            xycoords='data',
            xytext=(10, -15),  # New param
            textcoords='offset points',
           color='#8F84D3',
           fontname = "Arial")  # New param
axs[1].annotate(text='Transição no sentido\nda velocidade',
            xy=(2020, 0),
            xycoords='data',
            xytext=(55, -15),  # New param
            textcoords='offset points',
           color='#C3514E',
           fontname = "Arial")

plt.show()

# %% [markdown]
# #### Podemos ressaltar na avaliação gráfica os seguintes pontos:
# 1. No período que compreende **2010 - 2015** é possível identificar uma leve queda na cobertura vacinal
# 2. A partir do ano de 2016 até o ano de 2020, a cobertura vacinal contra a **Pólio** no Brasil passou a cair vertiginosamente, caindo inclusive abaixo de **95%**, meta estipulado pela OMS no programa de erradicação da **Polio** no mundo.
# 3. A taxa de variação da cobertura vacinal, na maior parte do tempo se encontra **no quadrante negativo do gráfico, indicando que o sentido do movimento da cobertura vacinal é para baixo**.

# %% [markdown]
# ## Taxa média da diminuição da cobertura vacinal no Brasil
# Nós vimos gráficamente que a cobertura vacinal está diminuindo ao longo do tempo, agora, será que um modelo de regressão linear poderia nos ajudar a entender como esses dados vem caindo?<br>
# Para tal, foi utilizada a biblioteca **Linregress** que faz a regressão linear.<br>
# Como estamos interessados na taxa média, eu vou utilizar como resposta (Y) `rolling_3`, que por ser filtrado acaba removendo um pouco do ruído.

# %%
lr_polio = linregress(x=polio_no_brasil.index, y=polio_no_brasil['rolling_3'])
print(f'slope = {lr_polio.slope: .2f}; rvalue = {lr_polio.rvalue: .2f}; pvalue = {lr_polio.pvalue: .3f}')
# Out:
# slope = -1.95; rvalue = -0.95; pvalue =  0.000

# %% [markdown]
# Podemos observar na regressão linear um valor muito bom para o **rvalue = -0.95**, com o pvalue rejeitando a *null hypothesis* de Slope == 0, e um **Slope de -1.95**<br>
# Esse slope de 1.95 mostra que na ultima década, houve uma queda de aproximadamente 1.95% ao ano na cobertura vacinal contra a **Poliomelite**.<br>
# Slope = -2.28 indica que desde 2010, a taxa de cobertura vêm caindo cerca de -2,28% em média por ano até o ano de 2020.<br><br>
# Parafechar a análise, vamos plotar um scatterplot desses dados para ter uma idéia visual de como está sendo o comportamento dos dados.

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10), sharex='all', sharey='all')
fig.tight_layout(pad=0.1)
sns.regplot(ax=axs[0], data=polio_no_brasil.reset_index(), x='index', y='rolling_3', color='#174A7E')
axs[0].set_title('Grafico de relação entre Cobertura Vacinal\n e os anos da ultima decada geral', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[0].set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].set_ylabel('Cobertura Vacinal contra Pólio [%]', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].spines['bottom'].set_visible(True)
axs[0].spines['bottom'].set_color('#555655')
axs[0].spines['bottom'].set_linewidth(1)
axs[0].spines['left'].set_visible(True)
axs[0].spines['left'].set_color('#555655')
axs[0].spines['left'].set_linewidth(1)
axs[0].set_facecolor('xkcd:white')
#ax.set_ylim(ymin=75, ymax=103)
axs[0].set_xlim(xmin=2009.5, xmax=2020.5)
axs[0].grid(b=True, axis='both', color='#DEDDDD', which='major')
for tick in axs[0].get_yticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
for tick in axs[0].get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
axs[0].annotate(text='Houve uma mudança de\ncomportamento entre 2015-16?',
            xy=(2015.65, 95),
            xycoords='data',
            xytext=(25, 50),
            textcoords='offset points',
            color='#C3514E',
           fontname = "Arial",
            fontsize=14,
            horizontalalignment='left',
            arrowprops={'color':'#C3514E', 'arrowstyle':'->'})


sns.regplot(ax=axs[1], data=polio_no_brasil.reset_index().query('index <= 2015'), x='index', y='rolling_3')
sns.regplot(ax=axs[1], data=polio_no_brasil.reset_index().query('index > 2015'), x='index', y='rolling_3')
axs[1].set_title('Grafico de relação entre Cobertura Vacinal\n e os anos da ultima decada antes e após 2016', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[1].set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].set_ylabel('', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].spines['bottom'].set_visible(True)
axs[1].spines['bottom'].set_color('#555655')
axs[1].spines['bottom'].set_linewidth(1)
axs[1].spines['left'].set_visible(True)
axs[1].spines['left'].set_color('#555655')
axs[1].spines['left'].set_linewidth(1)
axs[1].set_facecolor('xkcd:white')
axs[1].set_xlim(xmin=2009.5, xmax=2020.5)
axs[1].grid(b=True, axis='both', color='#DEDDDD', which='major')
for tick in axs[1].get_yticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
for tick in axs[1].get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
#axs[1].yaxis.labelpad = 20

plt.show()

# %% [markdown]
# Apesar de o modelo de regressão linear mostrar ótimos resultados estatísticos, e de o **Gráfico de relação entre Cobertura Vacinal e os alos da ultima decada (geral)** estarem bons, foi observada uma potêncial quebra no padrão de vacinação em 2016. Essa quebra de padrão é mostrada gráficamente no gráfico à direita. Os dois gráficos tem a mesma faixa em x e y, e um intervalo de confiança mais estreito no caso desse gráfico pode levar a imaginar que o erro é menor também.<br>
# De qualquer maneira, essa é uma informação que eu, por não conhecer tão bem a área, não tenho competência para avaliar no momento. Por esse motivo, vamos seguir utilizando os dados completos no decorrer da análise

# %% [markdown]
# ## Avaliação da cobertura vacinal no Brasil contra a **Pólio** na ultima decada por Unidade Federativa

# %% [markdown]
# A idéia aqui é apresentar 2 gráficos, destacando o estado en que a cobertura vacinal contra a pólio teve o melhor resultado e o estado com o pior resultado na ultima década. Os outros estados vão ser imprimidos em cinza, para evitar confundir o leitor. Os gráficos serão:
# 1. Gráfico de linhas mostrando o valor da média móvel (filtrado) ao longo da ultima década
# 2. Grafico de Slope, mostrando a taxa de variação média da cobertura vacinal na ultima década

# %%
# Caminho dos arquivos
path = r'../data/raw/cobertura_vacinal_uf/'

# Leitura dos arquivos extraídos do DATASUS
polio_por_estado = le_cobertura_vacinal_por_imuno_no_brasil_por_estado(path, 'Poliomielite')

# Impressão para avaliação
polio_por_estado.groupby('uf').min().sort_values(by='Polio_rol3').head()
# Out:
#                  ano  Poliomielite  Polio_rol3
# uf
# Amapá           2010        41.820      59.837
# Pará            2010        59.130      66.623
# Rio de Janeiro  2010        54.830      71.977
# Maranhão        2010        60.090      72.143
# Bahia           2010        69.620      74.233

# %%
tuplas = []
for uf in polio_por_estado['uf'].unique():
    mrl = linregress(polio_por_estado.query('uf == @uf')['ano'], polio_por_estado.query('uf == @uf')['Polio_rol3'])
    tuplas.append([uf, mrl.slope, mrl.rvalue, ])
lineregress_by_uf = pd.DataFrame(tuplas, columns=['uf', 'slope', 'r-sqrd'])
lineregress_by_uf.sort_values(by='slope').head()
# Out:
#                 uf  slope  r-sqrd
# 15            Pará -4.702  -0.959
# 2            Amapá -4.498  -0.953
# 9         Maranhão -4.010  -0.967
# 0             Acre -3.765  -0.928
# 20  Rio de Janeiro -3.191  -0.924

# %%
plt_polio_por_estado = polio_por_estado.copy()

high_slope_state = lineregress_by_uf.sort_values(by='slope').iloc[0]['uf']
high_slope_state_values = plt_polio_por_estado.query('uf == @high_slope_state')
plt_polio_por_estado = plt_polio_por_estado.query('uf != @high_slope_state')

low_slope_state = lineregress_by_uf.sort_values(by='slope').iloc[-1]['uf']
low_slope_state_values = plt_polio_por_estado.query('uf == @low_slope_state')
plt_polio_por_estado = plt_polio_por_estado.query('uf != @low_slope_state')

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(24, 10), gridspec_kw={'width_ratios': [2, 1]})
fig.tight_layout(pad=3)

for uf in plt_polio_por_estado['uf'].unique():
    sns.lineplot(ax=axs[0], data=plt_polio_por_estado.query('uf == @uf'), x='ano', y='Polio_rol3', color='#BFBEBE', alpha=0.5, linewidth=1, label=f'{uf}')
sns.lineplot(ax=axs[0], data=high_slope_state_values, x='ano', y='Polio_rol3', color='#E2533D', alpha=0.9, linewidth=2, label=f'{uf}')
sns.lineplot(ax=axs[0], data=low_slope_state_values, x='ano', y='Polio_rol3', color='#2380B7', alpha=0.9, linewidth=2, label=f'{uf}')

axs[0].set_title('Cobertura vacinal contra Pólio na ultima decada', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[0].axhline(95,linestyle='--',linewidth=1, alpha=0.8, color='#C3514E', label='OMS Target')
axs[0].set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].set_ylabel('Cobertura Vacinal contra Pólio [%]', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].spines['bottom'].set_visible(True)
axs[0].spines['bottom'].set_color('#555655')
axs[0].spines['bottom'].set_linewidth(1)
axs[0].spines['left'].set_visible(True)
axs[0].spines['left'].set_color('#555655')
axs[0].spines['left'].set_linewidth(1)
axs[0].set_facecolor('xkcd:white')
axs[0].grid(False)
axs[0].get_legend().remove()
for tick in axs[0].get_yticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
for tick in axs[0].get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
    
axs[0].annotate(text='Ceará [97.15%]',
            xy=(2020, 97.15),
            xycoords='data',
            xytext=(10, -5),  # New param
            textcoords='offset points',
           color='#2380B7',
           fontname = "Arial",
           fontsize=14)  # New param
axs[0].annotate(text='Pará [66.98%]',
                xy=(2020, 66.98),
                xycoords='data',
                xytext=(10, -5),  # New param
                textcoords='offset points',
                color='#E2533D',
                fontname = "Arial",
                fontsize=14)  # New paramv
axs[0].annotate(text='Meta OMS',
                xy=(2020, 95),
                xycoords='data',
                xytext=(45, -3),  # New param
                textcoords='offset points',
                color='#C3514E',
                fontname = "Arial",
                fontsize=14)

for uf in polio_por_estado['uf'].unique():
    sns.regplot(ax=axs[1], data=plt_polio_por_estado.query('uf == @uf'), x='ano', y='Polio_rol3', marker='', ci=False, line_kws={'alpha':0.5, 'color':'#BFBEBE', 'lw':1}, label=f'{uf}')
    
axs[1] = sns.regplot(data=high_slope_state_values, x='ano', y='Polio_rol3', marker='', ci=False, line_kws={'alpha':0.9, 'color':'#E2533D', 'lw':2}, label=f'{uf}')
axs[1] = sns.regplot(data=low_slope_state_values, x='ano', y='Polio_rol3', marker='', ci=False, line_kws={'alpha':0.9, 'color':'#2380B7', 'lw':2}, label=f'{uf}')

axs[1].set_title('Taxa média de diminuição da cobertura vacinal\npor UF na ultima decada', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[1].set_xlabel('', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].set_ylabel('', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].spines['bottom'].set_visible(False)
axs[1].spines['bottom'].set_color('#555655')
axs[1].spines['bottom'].set_linewidth(1)
axs[1].spines['left'].set_visible(False)
axs[1].spines['left'].set_color('#555655')
axs[1].spines['left'].set_linewidth(1)
axs[1].set_facecolor('xkcd:white')
axs[1].set_xlim(xmin=2009.5, xmax=2020.5)
axs[1].set_ylim(ymax=113.5)
axs[1].grid(False)
axs[1].set_yticks([])
axs[1].set_xticks([])
axs[1].annotate(text='Pará -4.70 [% / ano]',
            xy=(2020.1, 61.3),
            xycoords='data',
            xytext=(10, -5),  # New param
            textcoords='offset points',
           color='#E2533D',
           fontname = "Arial")

axs[1].annotate(text='Ceará -0.06 [% / ano]',
            xy=(2020.1, 102),
            xycoords='data',
            xytext=(0, 0),  # New param
            textcoords='offset points',
           color='#2380B7',
           fontname = "Arial")


plt.show()

# %% [markdown]
# É possível observar uma tendência geral de diminuição na cobertura vacinal contra a **Pólio** na ultima década.
#
# **Pontos relevantes:**
# 1. Somente o estado do **Ceará** terminou 2020 com uma cobertura vacinal acima da *meta da OMS*
# 2. Todos os estados mostram uma queda, no gráfico de slope é possível ver que todos os slopes foram negativos, alguns com maior outros com menor intensidade.
# 3. Não podemos simplesmente fazer a média, uma vez que precisa se ponderar pela quantidade de indivíduos na faixa davascinação, porém, a análise por estado mostra que não temos somente um ou outro estado muito populoso puxando a média do país para baixo, e sim que essa tendência de diminuição é sistemica em todos os estados do País.

# %% [markdown]
# ## Municipios
# O ano de **2019** foi selecionado para evitar considerar o ano **2020** de pandemia.<br>
# A Idéia aqui é fazer uma análise geral dos municipios, verificando a distribuição de cobertura vacinalm bem como quais seriam os municípios menos imunizados nesse ano, e qual é o valor de cobertura vacinal contra a **Pólio** nesses municípios.

# %%
# Cobertura vacinal por município no ano de 2019
cobertura_municipio = pd.read_csv(r'../data/raw/cobertura_vacinal_municipio/cobertura_vacinal_por_municipio_2019.csv', sep=';', decimal=',', encoding='ISO-8859-1',
                         skipfooter=1, engine='python')
cobertura_municipio = cobertura_municipio[['Município', 'Poliomielite']]
cobertura_municipio[['municipio_no','municipio']] = pd.DataFrame(cobertura_municipio['Município'].str.split(' ', 1).tolist())
cobertura_municipio = cobertura_municipio.drop('Município', axis=1)
cobertura_municipio['municipio'] = cobertura_municipio['municipio'].str.replace(r"D\\",r"D", regex=True)
cobertura_municipio['municipio_no'] = cobertura_municipio['municipio_no'].astype(int)
cobertura_municipio.sort_values(by='Poliomielite').head()
# Out:
#       Poliomielite  municipio_no             municipio
# 2107         4.230        292300           NOVA VICOSA
# 4755         5.710        430710                HERVAL
# 3351         6.980        350745                BOREBI
# 4973        10.940        431700  SANTANA DA BOA VISTA
# 4642        13.210        430187       BARRA DO QUARAI

# %%
# Eu gostaria de plotar juntamente com o nome do município, o UF do estado, para isso, vamos pegar essa tabela da internet.
cod_uf = pd.DataFrame(pd.read_html('https://www.oobj.com.br/bc/article/quais-os-c%C3%B3digos-de-cada-uf-no-brasil-465.html')[0])
cod_uf.columns = ['codigo', 'estado', 'uf']
cod_uf['estado'] = cod_uf['estado'].replace(r' \(\*\)', r'', regex=True)

# %%
# Eu gostaria de plotar juntamente com o nome do município, o UF do estado, para isso, vamos pegar essa tabela da internet.
codigo_municipio_ibge = pd.read_html('https://www.ibge.gov.br/explica/codigos-dos-municipios.php')
cod_municipio = codigo_municipio_ibge[1:].copy()
for i in range(0,len(cod_municipio)):
    cod_municipio[i]['uf'] = cod_municipio[i].columns[0][14:]
    cod_municipio[i].columns = ['municipio', 'municipio_no', 'estado']
municipio = pd.concat(cod_municipio, ignore_index=True)
municipio['estado'] = municipio['estado'].replace('al', 'Distrito Federal')
municipio['municipio'] = municipio['municipio'].str.replace(r"D\\",r"D", regex=True)
municipio = municipio.merge(cod_uf, left_on='estado', right_on='estado')
municipio['uf_municipio'] = municipio['uf'].str.cat(municipio['municipio'], sep=': ')
municipio['municipio_no'] = municipio['municipio_no'].astype(str).str[:-1].astype(int)
municipio.head()
# Out:
#       municipio  municipio_no estado  codigo  uf      uf_municipio
# 0    Acrelândia        120001   Acre      12  AC    AC: Acrelândia
# 1  Assis Brasil        120005   Acre      12  AC  AC: Assis Brasil
# 2     Brasiléia        120010   Acre      12  AC     AC: Brasiléia
# 3        Bujari        120013   Acre      12  AC        AC: Bujari
# 4      Capixaba        120017   Acre      12  AC      AC: Capixaba

# %%
cobertura_municipio_completo = cobertura_municipio.merge(municipio, left_on='municipio_no', right_on='municipio_no')
cobertura_municipio_completo = cobertura_municipio_completo.drop('municipio_x', axis=1)
cobertura_municipio_completo = cobertura_municipio_completo.rename(columns={'municipio_y' : 'municipio'})
cobertura_municipio_completo = cobertura_municipio_completo.set_index('municipio_no')
cobertura_municipio_completo.head()
print('Top 10 municípios menos imunizados em 2019')
cobertura_municipio_completo.sort_values(by='Poliomielite')[:10]
# Out:
# Top 10 municípios menos imunizados em 2019
#               Poliomielite              municipio             estado  codigo  \
# municipio_no
# 292300               4.230            Nova Viçosa              Bahia      29
# 430710               5.710                 Herval  Rio Grande do Sul      43
# 350745               6.980                 Borebi          São Paulo      35
# 431700              10.940   Santana da Boa Vista  Rio Grande do Sul      43
# 430187              13.210        Barra do Quaraí  Rio Grande do Sul      43
# 220210              16.070      Campinas do Piauí              Piauí      22
# 291840              17.250               Juazeiro              Bahia      29
# 510300              17.390  Chapada dos Guimarães        Mato Grosso      51
# 210547              17.730   Jenipapo dos Vieiras           Maranhão      21
# 351970              18.010                 Ibiúna          São Paulo      35
#
#               uf               uf_municipio
# municipio_no
# ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(24, 10), gridspec_kw={'width_ratios': [1, 1]})
fig.tight_layout(pad=3)

sns.barplot(ax=axs[0], data=cobertura_municipio_completo.sort_values(by='Poliomielite')[:10], x='Poliomielite', y='uf_municipio', color='#94AFC5')
axs[0].set_title('Top 10 municípios que menos vacinaram em 2019', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[0].set_xlabel('% Cobertura vacinal contra Pólio', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].set_ylabel('', fontsize=12, family='Arial', style='italic', color='#555655')
axs[0].spines['bottom'].set_visible(True)
axs[0].spines['bottom'].set_color('#555655')
axs[0].spines['bottom'].set_linewidth(1)
axs[0].spines['left'].set_visible(False)
axs[0].spines['left'].set_color('#555655')
axs[0].spines['left'].set_linewidth(1)
axs[0].set_facecolor('xkcd:white')

for tick in axs[0].get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
i = 0
for municipio_no in cobertura_municipio_completo.sort_values(by='Poliomielite').index[:10]:
    x = cobertura_municipio_completo.loc[municipio_no]['Poliomielite']
    axs[0].annotate(text=f'{x}%',
                xy=(x, i),
                xycoords='data',
                xytext=(10, 0),  # New param
                textcoords='offset points',
               color='#94AFC5',
               fontname = "Arial")
    i+=1
axs[0].annotate(text='Meta OMS 95%',
            xy=(16, -0.2),
            xycoords='data',
            xytext=(10, 0),  # New param
            textcoords='offset points',
           color='#C3514E',
           fontname = "Arial",
               bbox=dict(boxstyle='round', fc='0.8', fill=False, color='#555655'),   # New param
            ha='center',
            va='center')


axs[1] = sns.histplot( cobertura_municipio_completo['Poliomielite'], color='#94AFC5')
axs[1].axvspan(95, 100, alpha=0.5, color='#9ABB59')
axs[1].axvspan(0, 95, alpha=0.05, color='#C3514E')
axs[1].axvspan(100, 400, alpha=0.05, color='#C3514E')
axs[1].set_title('Distribuição da cobertura vacinal por município em 2019', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
axs[1].set_xlabel('% Cobertura vacinal}', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].set_ylabel('Count of observations', fontsize=12, family='Arial', style='italic', color='#555655')
axs[1].spines['bottom'].set_visible(True)
axs[1].spines['bottom'].set_color('#555655')
axs[1].spines['bottom'].set_linewidth(1)
axs[1].spines['left'].set_visible(True)
axs[1].spines['left'].set_color('#555655')
axs[1].spines['left'].set_linewidth(1)
axs[1].set_facecolor('xkcd:white')
axs[1].set_xlim(xmin=0, xmax=400)
axs[1].grid(b=True, axis='both', color='#DEDDDD', which='major')
for tick in axs[1].get_yticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
for tick in axs[1].get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')

axs[1].annotate(text='Faixa ótima de vacinação\nentre 95% - 100%',
            xy=(100, 350),
            xycoords='data',
            xytext=(10, 0),  # New param
            textcoords='offset points',
           color='#9ABB59',
           fontname = "Arial")
text = '''1. <95% - População com exposição além da
    recomendada pela OMS ao virus da Pólio

2. >100% - População esteve exposta de algum
    momento do passado até esse ano'''
axs[1].annotate(text=text,
            xy=(150, 150),
            xycoords='data',
            xytext=(10, 0),  # New param
            textcoords='offset points',
           color='#C3514E',
           fontname = "Arial")
plt.show()

# %%
faixa_95_100 = cobertura_municipio_completo.query('Poliomielite >= 95 and Poliomielite <= 100')['Poliomielite'].size
total = cobertura_municipio_completo['Poliomielite'].size
print(f'Em 2020, somente {total / faixa_95_100: .2f}% dos municípios do Brasil tiveram a cobertura vacinal contra Póliomielite conforme o proposto pela OMS')
# Out:
# Em 2020, somente  9.28% dos municípios do Brasil tiveram a cobertura vacinal contra Póliomielite conforme o proposto pela OMS

# %% [raw]
# cobertura_municipio_completo['Poliomielite'].mean(), cobertura_municipio_completo['Poliomielite'].describe()

# %% [markdown]
# Pontos a observar:
# 1. A **Média** da cobertura vacial contra a **Pólio** no Brasil em 2019 tem o valor de 94%, mais quando comparado com a **Mediana** que tem 91,5, podemos ver que a média está sendo puxada para cima por causa de poucos municípios, que fogem a regra geral, e que vacinaram em 2019 mais de 200% da população alvo.
# 2. Esses valores elevados podem ser resultado de alguma campanha de vacinação municipal. Essa pesquisa Não faz parte do escopo desse projeto.
# 3. Valores altos não são bons indicadores. Eles significam que a população ficou exposta ao viros em algum período anterior, e que as medidas públicas de concientização cotidianas não são eficientes, precisando de campanhas para mobilizar a população.
# 4. Valores baixos significam exposição ao vírus, e as doenças relacionadas a **Pólio**
# 5. A média nesse caso não pode ser usada para idéia geral do país, uma vez que se precisa ponderar pela população alvo da vacinação nesse ano, para que então esse dado seja representativo para uma comparação nacional.
# 5. Não vemos no **#TOP10 piores** uma regionalização, pois temos municípios do Sul ao Norte do país

# %% [markdown]
# ## Essa diminuição na imunização acontece somente com a Poliomielite? ou também acontece com outros imunos no Brasil?

# %%
# Cobertura da vacinação contra Poliomelite no Brasil

path = r'../data/raw/cobertura_vacinal_brasil/cobertura_por_imuno_por_ano_1994-2021.csv'
HepatiteB_no_brasil = le_cobertura_vacinal_por_imuno_no_brasil(path, 'Hepatite B')

MeningococoC_no_brasil = le_cobertura_vacinal_por_imuno_no_brasil(path, 'Meningococo C', 3, 1)
display(HepatiteB_no_brasil.loc[2013:].tail())
display(MeningococoC_no_brasil.loc[2013:].tail())
# Out:
# ano   Hepatite B  rolling_3  rolling_vel  rolling_acel
# 2016     105.190     99.783        1.543         1.187
# 2017      84.400     95.777       -4.007        -5.550
# 2018      88.530     92.707       -3.070         0.937
# 2019      70.770     81.233      -11.473        -8.403
# 2020      76.950     78.750       -2.483         8.990
# ano   Meningococo C  rolling_3  rolling_vel  rolling_acel
# 2016         91.680     95.410       -2.673        -3.343
# 2017         87.440     92.437       -2.973        -0.300
# 2018         88.490     89.203       -3.233        -0.260
# 2019         87.410     87.780       -1.423         1.810
# 2020         78.230     84.710       -3.070        -1.647

# %%
polio_no_brasil.loc[2011:]
# Out:
# ano   Poliomielite  rolling_3  rolling_vel  rolling_acel
# 2011       101.330    101.447        0.383         2.410
# 2012        96.550     99.077       -2.370        -2.753
# 2013       100.710     99.530        0.453         2.823
# 2014        96.760     98.007       -1.523        -1.977
# 2015        98.290     98.587        0.580         2.103
# 2016        84.430     93.160       -5.427        -6.007
# 2017        84.740     89.153       -4.007         1.420
# 2018        89.540     86.237       -2.917         1.090
# 2019        84.190     86.157       -0.080         2.837
# 2020        75.860     83.197       -2.960        -2.880

# %%
plt.figure(figsize=(20,10))
ax = sns.lineplot(data=HepatiteB_no_brasil.loc[2010:], x=polio_no_brasil.loc[2010:].index, y='rolling_3', color='#F79747')
ax = sns.lineplot(data=MeningococoC_no_brasil.loc[2013:], x=polio_no_brasil.loc[2013:].index, y='rolling_3', color='#94678D')
ax = sns.lineplot(data=polio_no_brasil.loc[2010:], x=polio_no_brasil.loc[2010:].index, y='rolling_3', color='#174A7E', marker='o')
ax.set_title('Comparação Cobertura vacinal entre 3 imunos\nPoliomielite; Meningococo C; Hepatite B', fontsize=24, loc='left', family='Arial', color='#555655', pad=20)
ax.set_xlabel('Ano', fontsize=12, family='Arial', style='italic', color='#555655')
ax.set_ylabel('Cobertura Vacinal [%]', fontsize=12, family='Arial', style='italic', color='#555655')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color('#555655')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_visible(True)
ax.spines['left'].set_color('#555655')
ax.spines['left'].set_linewidth(1)
ax.set_facecolor('xkcd:white')
#axs[1].set_xlim(xmin=2009.5, xmax=2020.5)
#ax.grid(b=True, axis='both', color='#DEDDDD', which='major')
ax.grid(False)
for tick in ax.get_yticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
for tick in ax.get_xticklabels():
    tick.set_fontname("Arial")
    tick.set_fontsize(12)
    tick.set_color('#555655')
    
ax.annotate(text='Poliomielite',
            xy=(2020, 83.2),
            xycoords='data',
            xytext=(10, -5),  # New param
            textcoords='offset points',
           color='#174A7E',
           fontname = "Arial")
ax.annotate(text='Hepatite B',
            xy=(2020, 78.75),
            xycoords='data',
            xytext=(10, -5),  # New param
            textcoords='offset points',
           color='#F79747',
           fontname = "Arial")
ax.annotate(text='Meningococo C',
            xy=(2020, 84.71),
            xycoords='data',
            xytext=(10, -5),  # New param
            textcoords='offset points',
           color='#94678D',
           fontname = "Arial")
plt.show()

# %% [markdown]
# A **Meningococo C** e a **Hepatite B** foram imunos escolhidos por serem umunizantes que apresentam valores desde meados de 2010.<br>
# Aparentemente existe um decaimento na cobertura vacinal, que não está excluasivamnete relacionado com o imuno da **Poliomielite**, uma vez que para outros imunos também vemos um decaimento a partir de meados de 2016.

# %% [markdown]
# ## Conclusões a cerca da pesquisa
#
# - A **Cobertura Vacinal contra a Poliomielite no Brasil**, objeto fundamental dessa pesquisa, vem caindo consistentemente na ultima década.<br>
# - Desde **2016** A cobertura vacinal do Brasil fica abaixo da méta estipulada pela **OMS** no **Programa de Erradicação da Poliomielite no Mundo**, o que é grave, pela severidade da doença e o risco de exposição.
# - **Todas as Unidades Federativas do Brasil**, em maior ou menor proporção, apresentaram **queda na cobertura vacinal contra a Piliomielite na ultima década**
#     - O estado do Pará atingiu a menor taxa média de decaimento, com valor de quase **5%** ao ano de retração na cobertura vacinal contra a **Poliomielite**.
#     - O Estado do Amapá, em **2020**, vacinou somente 41% das crianças contra a **Poliomielite**, enquanto a **Meta da OMS é de 95%**.
# - Uma análise por município mostra que:
#     - Olhando para o **TOP 10 municípios que menos imunizaram em 2020** (com menor cobertura vacinal) é possível observar municípios de muitas regiões diferentes: Sul, Sudeste, Centro-Oeste, Norte e Nordeste, logo, parece ser um problema sistêmico para a nação.
#     - Os 3 municípios que menos imunizaram em 2020 são: **Nova Viçosa - BA [4.23%], Herval - RS [5.71%] e Borebi - SP [6.98%]**, com valores muito abaixo do recomendado pela **OMS** de **95%**.
#     - Somente cerca de **10% dos municípios** estiveram ente a faixa ideal de **95% até 100%**.
#     - Os 90% dos municípios que estão acima ou abaixo dessa faixa representa um risco:
#         - **Risco Futuro** no caso dos Municípios que imunizaram menos de 95% de sua população alvo.
#         - **Risco Passado** no caso dos Municípios que vacinaram mais que 100%, uma vez que essa comunidade ficou exposta ao risco de contaminção até o ano em questão.
# - A redução da cobertura vacinal não aparenta ser exclusiva do imuno contra a **Poliomielite**, mais sim um problema relacionado com a imunização em geral, uma vez que vacinas contra a **Meningite e Hepatite** também tiveram um comportamento de certa forma equivalente ao da **Pólio**.
#
# ## Proximos passos
# - Investigação sobre a relação do crescimento e difusão da ideologia **anti-vac** na internet, talvez buscando pela quantidade de alguns termos chave no *Twitter* por exemplo, e correlacionar com essa diminuição na cobertura vacinal
# - Investigar as campanhas de vacinação e dinheiro gasto na publicidade das mesmas.
# - Tentar uma entrevista com alguem do departamento de saúde pública (alguém de um posto de saúde, de uma UBS, etc...), para verificar se a categoria clínica consegue justificar o motivo da queda na cobertura.

# %% [markdown]
# ## Proximas ações:
#
# - [ ] Criar links e estrutura de Sumário
# - [ ] Melhorar a parte descritiva no geral
# - [ ] Criar um arquivo de métodos separado
# - [ ] Criar uma função de layout e formatação do gráfico
# - [ ] Colocar o DocString das funções
# - [ ] Dividir em notebooks separados a análise no nível nacional, estadual e municipal
